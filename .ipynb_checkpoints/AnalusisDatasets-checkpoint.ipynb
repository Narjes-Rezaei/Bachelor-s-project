# %%
import pandas as pd
import numpy as np
import ast

# %%
import sys
print(sys.executable)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/bin/python3.12

# %%
movies = pd.read_csv('datasets/tmdb_5000_movies.csv')
movies.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
# 3  [{"id": 849, "name": "dc comics"}, {"id": 853,...                en
# 4  [{"id": 818, "name": "based on novel"}, {"id":...                en
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                             overview  popularity  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615
# 2  A cryptic message from Bond’s past sends him o...  107.376788
# 3  Following the death of District Attorney Harve...  112.312950
# 4  John Carter is a war-weary, former military ca...   43.926995
#
#                                 production_companies  \
# 0  [{"name": "Ingenious Film Partners", "id": 289...
# 1  [{"name": "Walt Disney Pictures", "id": 2}, {"...
# 2  [{"name": "Columbia Pictures", "id": 5}, {"nam...
# 3  [{"name": "Legendary Pictures", "id": 923}, {"...
# 4        [{"name": "Walt Disney Pictures", "id": 2}]
#
#                                 production_countries release_date     revenue  \
# 0  [{"iso_3166_1": "US", "name": "United States o...   2009-12-10  2787965087
# 1  [{"iso_3166_1": "US", "name": "United States o...   2007-05-19   961000000
# 2  [{"iso_3166_1": "GB", "name": "United Kingdom"...   2015-10-26   880674609
# 3  [{"iso_3166_1": "US", "name": "United States o...   2012-07-16  1084939099
# 4  [{"iso_3166_1": "US", "name": "United States o...   2012-03-07   284139100
#
#    runtime                                   spoken_languages    status  \
# 0    162.0  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 1    169.0           [{"iso_639_1": "en", "name": "English"}]  Released
# 2    148.0  [{"iso_639_1": "fr", "name": "Fran\u00e7ais"},...  Released
# 3    165.0           [{"iso_639_1": "en", "name": "English"}]  Released
# 4    132.0           [{"iso_639_1": "en", "name": "English"}]  Released
#
#                                           tagline  \
# 0                     Enter the World of Pandora.
# 1  At the end of the world, the adventure begins.
# 2                           A Plan No One Escapes
# 3                                 The Legend Ends
# 4            Lost in our world, found in another.
#
#                                       title  vote_average  vote_count
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500
# 2                                   Spectre           6.3        4466
# 3                     The Dark Knight Rises           7.6        9106
# 4                               John Carter           6.1        2124

# %%
credits = pd.read_csv('datasets/tmdb_5000_credits.csv')
credits.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 4  [{"credit_id": "52fe479ac3a36847f813eaa3", "de...

# %%
tmdb = movies.merge(credits, on="title")
tmdb.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
# 3  [{"id": 849, "name": "dc comics"}, {"id": 853,...                en
# 4  [{"id": 818, "name": "based on novel"}, {"id":...                en
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                             overview  popularity  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615
# 2  A cryptic message from Bond’s past sends him o...  107.376788
# 3  Following the death of District Attorney Harve...  112.312950
# 4  John Carter is a war-weary, former military ca...   43.926995
#
#                                 production_companies  ... runtime  \
# 0  [{"name": "Ingenious Film Partners", "id": 289...  ...   162.0
# 1  [{"name": "Walt Disney Pictures", "id": 2}, {"...  ...   169.0
# 2  [{"name": "Columbia Pictures", "id": 5}, {"nam...  ...   148.0
# 3  [{"name": "Legendary Pictures", "id": 923}, {"...  ...   165.0
# 4        [{"name": "Walt Disney Pictures", "id": 2}]  ...   132.0
#
#                                     spoken_languages    status  \
# 0  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 1           [{"iso_639_1": "en", "name": "English"}]  Released
# 2  [{"iso_639_1": "fr", "name": "Fran\u00e7ais"},...  Released
# 3           [{"iso_639_1": "en", "name": "English"}]  Released
# 4           [{"iso_639_1": "en", "name": "English"}]  Released
#
#                                           tagline  \
# 0                     Enter the World of Pandora.
# 1  At the end of the world, the adventure begins.
# 2                           A Plan No One Escapes
# 3                                 The Legend Ends
# 4            Lost in our world, found in another.
#
#                                       title vote_average vote_count movie_id  \
# 0                                    Avatar          7.2      11800    19995
# 1  Pirates of the Caribbean: At World's End          6.9       4500      285
# 2                                   Spectre          6.3       4466   206647
# 3                     The Dark Knight Rises          7.6       9106    49026
# 4                               John Carter          6.1       2124    49529
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 4  [{"credit_id": "52fe479ac3a36847f813eaa3", "de...
#
# [5 rows x 23 columns]

# %%
tmdb = tmdb [[
    'title',
    'genres',
    'cast',
    'crew',
    'release_date'
]]
tmdb.head()
# Out:
#                                       title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                               genres  \
# 0  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew release_date
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...   2009-12-10
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...   2007-05-19
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...   2015-10-26
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...   2012-07-16
# 4  [{"credit_id": "52fe479ac3a36847f813eaa3", "de...   2012-03-07

# %%
def get_director(crew):
    crew = ast.literal_eval(crew)
    for person in crew:
        if person ['job'] == 'Director':
            return person['name']
    return None

tmdb['director'] = tmdb['crew'].apply(get_director)
tmdb.head()
# Out:
#                                       title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                               genres  \
# 0  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew release_date  \
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...   2009-12-10
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...   2007-05-19
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...   2015-10-26
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...   2012-07-16
# 4  [{"credit_id": "52fe479ac3a36847f813eaa3", "de...   2012-03-07
#
#             director
# 0      James Cameron
# 1     Gore Verbinski
# 2         Sam Mendes
# 3  Christopher Nolan
# 4     Andrew Stanton

# %%
def get_cast(cast):
    cast = ast.literal_eval(cast)
    return [actor['name'] for actor in cast[:5]]

tmdb['actors'] = tmdb['cast'].apply(get_cast)
tmdb.head()
# Out:
#                                       title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                               genres  \
# 0  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew release_date  \
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...   2009-12-10
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...   2007-05-19
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...   2015-10-26
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...   2012-07-16
# 4  [{"credit_id": "52fe479ac3a36847f813eaa3", "de...   2012-03-07
#
#             director                                             actors
# 0      James Cameron  [Sam Worthington, Zoe Saldana, Sigourney Weave...
# 1     Gore Verbinski  [Johnny Depp, Orlando Bloom, Keira Knightley, ...
# 2         Sam Mendes  [Daniel Craig, Christoph Waltz, Léa Seydoux, R...
# 3  Christopher Nolan  [Christian Bale, Michael Caine, Gary Oldman, A...
# 4     Andrew Stanton  [Taylor Kitsch, Lynn Collins, Samantha Morton,...

# %%
def extract_names(text):
    text = ast.literal_eval(text)
    return [item['name'] for item in text]

tmdb['genres'] = tmdb['genres'].apply(extract_names)
tmdb.head()
# Out:
#                                       title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1                   [Adventure, Fantasy, Action]
# 2                     [Action, Adventure, Crime]
# 3               [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, Science Fiction]
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew release_date  \
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...   2009-12-10
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...   2007-05-19
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...   2015-10-26
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...   2012-07-16
# 4  [{"credit_id": "52fe479ac3a36847f813eaa3", "de...   2012-03-07
#
#             director                                             actors
# 0      James Cameron  [Sam Worthington, Zoe Saldana, Sigourney Weave...
# 1     Gore Verbinski  [Johnny Depp, Orlando Bloom, Keira Knightley, ...
# 2         Sam Mendes  [Daniel Craig, Christoph Waltz, Léa Seydoux, R...
# 3  Christopher Nolan  [Christian Bale, Michael Caine, Gary Oldman, A...
# 4     Andrew Stanton  [Taylor Kitsch, Lynn Collins, Samantha Morton,...

# %%
print(tmdb.columns)
tmdb.shape
# Out:
# Index(['title', 'genres', 'cast', 'crew', 'release_date', 'director',
#        'actors'],
#       dtype='object')
# (4809, 7)

# %%
tmdb['year'] = pd.to_datetime(tmdb['release_date'], errors='coerce').dt.year
tmdb['year'] = tmdb['year'].astype('Int64')
print(list(tmdb.columns))
# tmdb.head()
# Out:
# ['title', 'genres', 'cast', 'crew', 'release_date', 'director', 'actors', 'year']

# %%
tmdb = tmdb.drop(columns=['cast', 'crew', 'release_date'])
tmdb.head()
# Out:
#                                       title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                           genres           director  \
# 0  [Action, Adventure, Fantasy, Science Fiction]      James Cameron
# 1                   [Adventure, Fantasy, Action]     Gore Verbinski
# 2                     [Action, Adventure, Crime]         Sam Mendes
# 3               [Action, Crime, Drama, Thriller]  Christopher Nolan
# 4           [Action, Adventure, Science Fiction]     Andrew Stanton
#
#                                               actors  year
# 0  [Sam Worthington, Zoe Saldana, Sigourney Weave...  2009
# 1  [Johnny Depp, Orlando Bloom, Keira Knightley, ...  2007
# 2  [Daniel Craig, Christoph Waltz, Léa Seydoux, R...  2015
# 3  [Christian Bale, Michael Caine, Gary Oldman, A...  2012
# 4  [Taylor Kitsch, Lynn Collins, Samantha Morton,...  2012

# %%
imdb = pd.read_csv('datasets/imdb_top_1000.csv')
imdb.head()
# Out:
#                                          Poster_Link  \
# 0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3  https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4  https://m.media-amazon.com/images/M/MV5BMWU4N2...
#
#                       title  year Certificate  Runtime                 genre  \
# 0  The Shawshank Redemption  1994           A  142 min                 Drama
# 1             The Godfather  1972           A  175 min          Crime, Drama
# 2           The Dark Knight  2008          UA  152 min  Action, Crime, Drama
# 3    The Godfather: Part II  1974           A  202 min          Crime, Drama
# 4              12 Angry Men  1957           U   96 min          Crime, Drama
#
#    imdb_rating                                           Overview  Meta_score  \
# 0          9.3  Two imprisoned men bond over a number of years...        80.0
# 1          9.2  An organized crime dynasty's aging patriarch t...       100.0
# 2          9.0  When the menace known as the Joker wreaks havo...        84.0
# 3          9.0  The early life and career of Vito Corleone in ...        90.0
# 4          9.0  A jury holdout attempts to prevent a miscarria...        96.0
#
#                director          actor1          actor2         actor3  \
# 0        Frank Darabont     Tim Robbins  Morgan Freeman     Bob Gunton
# 1  Francis Ford Coppola   Marlon Brando       Al Pacino     James Caan
# 2     Christopher Nolan  Christian Bale    Heath Ledger  Aaron Eckhart
# 3  Francis Ford Coppola       Al Pacino  Robert De Niro  Robert Duvall
# 4          Sidney Lumet     Henry Fonda     Lee J. Cobb  Martin Balsam
#
#            actor4  No_of_Votes        Gross
# 0  William Sadler      2343110   28,341,469
# 1    Diane Keaton      1620367  134,966,411
# 2   Michael Caine      2303232  534,858,444
# 3    Diane Keaton      1129952   57,300,000
# 4    John Fiedler       689845    4,360,000

# %%
imdb.columns
# Out:
# Index(['Poster_Link', 'title', 'year', 'Certificate', 'Runtime', 'genre',
#        'imdb_rating', 'Overview', 'Meta_score', 'director', 'actor1', 'actor2',
#        'actor3', 'actor4', 'No_of_Votes', 'Gross'],
#       dtype='object')

# %%
imdb['actors_imdb'] = imdb[['actor1', 'actor2','actor3', 'actor4']].values.tolist()
imdb['year'] = pd.to_numeric(imdb['year'], errors='coerce').astype('Int64')
imdb = imdb[['title', 'year', 'imdb_rating', 'actors_imdb']]
imdb.head()
# Out:
#                       title  year  imdb_rating  \
# 0  The Shawshank Redemption  1994          9.3
# 1             The Godfather  1972          9.2
# 2           The Dark Knight  2008          9.0
# 3    The Godfather: Part II  1974          9.0
# 4              12 Angry Men  1957          9.0
#
#                                          actors_imdb
# 0  [Tim Robbins, Morgan Freeman, Bob Gunton, Will...
# 1  [Marlon Brando, Al Pacino, James Caan, Diane K...
# 2  [Christian Bale, Heath Ledger, Aaron Eckhart, ...
# 3  [Al Pacino, Robert De Niro, Robert Duvall, Dia...
# 4  [Henry Fonda, Lee J. Cobb, Martin Balsam, John...

# %%
final_data = tmdb.merge(imdb, on=['title', 'year'], how='left')
final_data.head()
# Out:
#                                       title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                           genres           director  \
# 0  [Action, Adventure, Fantasy, Science Fiction]      James Cameron
# 1                   [Adventure, Fantasy, Action]     Gore Verbinski
# 2                     [Action, Adventure, Crime]         Sam Mendes
# 3               [Action, Crime, Drama, Thriller]  Christopher Nolan
# 4           [Action, Adventure, Science Fiction]     Andrew Stanton
#
#                                               actors  year  imdb_rating  \
# 0  [Sam Worthington, Zoe Saldana, Sigourney Weave...  2009          7.8
# 1  [Johnny Depp, Orlando Bloom, Keira Knightley, ...  2007          NaN
# 2  [Daniel Craig, Christoph Waltz, Léa Seydoux, R...  2015          NaN
# 3  [Christian Bale, Michael Caine, Gary Oldman, A...  2012          8.4
# 4  [Taylor Kitsch, Lynn Collins, Samantha Morton,...  2012          NaN
#
#                                          actors_imdb
# 0  [Sam Worthington, Zoe Saldana, Sigourney Weave...
# 1                                                NaN
# 2                                                NaN
# 3  [Christian Bale, Tom Hardy, Anne Hathaway, Gar...
# 4                                                NaN

# %%
final_data = final_data[[
    'title',
    'genres',
    'actors',
    'director',
    'year',
    'imdb_rating'
]]
final_data.head()
final_data.shape
# Out:
# (4809, 6)

# %%
final_data.head(4000)
# Out:
#                                          title  \
# 0                                       Avatar
# 1     Pirates of the Caribbean: At World's End
# 2                                      Spectre
# 3                        The Dark Knight Rises
# 4                                  John Carter
# ...                                        ...
# 3995                               Ulee's Gold
# 3996                        The Black Stallion
# 3997                                 Sardaarji
# 3998                         Journey to Saturn
# 3999                            Donovan's Reef
#
#                                                  genres  \
# 0         [Action, Adventure, Fantasy, Science Fiction]
# 1                          [Adventure, Fantasy, Action]
# 2                            [Action, Adventure, Crime]
# 3                      [Action, Crime, Drama, Thriller]
# 4                  [Action, Adventure, Science Fiction]
# ...                                                 ...
# 3995                                            [Drama]
# 3996                                [Adventure, Family]
# 3997                                                 []
# 3998  [Action, Adventure, Animation, Comedy, Science...
# 3999                       [Adventure, Comedy, Romance]
#
#                                                  actors  \
# 0     [Sam Worthington, Zoe Saldana, Sigourney Weave...
# 1     [Johnny Depp, Orlando Bloom, Keira Knightley, ...
# 2     [Daniel Craig, Christoph Waltz, Léa Seydoux, R...
# 3     [Christian Bale, Michael Caine, Gary Oldman, A...
# 4     [Taylor Kitsch, Lynn Collins, Samantha Morton,...
# ...                                                 ...
# 3995  [Peter Fonda, Patricia Richardson, Christine D...
# 3996  [Kelly Reno, Mickey Rooney, Teri Garr, Clarenc...
# 3997                                                 []
# 3998  [Casper Christensen, Frank Hvam, Ali Kazim, Ib...
# 3999  [John Wayne, Elizabeth Allen, Lee Marvin, Cesa...
#
#                         director  year  imdb_rating
# 0                  James Cameron  2009          7.8
# 1                 Gore Verbinski  2007          NaN
# 2                     Sam Mendes  2015          NaN
# 3              Christopher Nolan  2012          8.4
# 4                 Andrew Stanton  2012          NaN
# ...                          ...   ...          ...
# 3995                Victor Nunez  1997          NaN
# 3996             Carroll Ballard  1979          NaN
# 3997                Rohit Jugraj  2015          NaN
# 3998  Kresten Vestbjerg Andersen  2008          NaN
# 3999                   John Ford  1963          NaN
#
# [4000 rows x 6 columns]

# %%
from neo4j import GraphDatabase
import pandas as pd

URI = "bolt://localhost:7687"
USER = "neo4j"
PASSWORD = "Saleh.4992"

class MovieGraph:
    def __init__(self, uri, user, password):
        self.driver = GraphDatabase.driver(uri, auth=(user, password))

    def close(self):
        self.driver.close()

    def add_movies(self, df):
        with self.driver.session() as session:
         for _, row in df.iterrows():

            genres = row['genres'] if isinstance(row['genres'], list) else ['none']
            actors = row['actors'] if isinstance(row['actors'], list) else ['none']

            session.execute_write(
               self._create_full_movie,
               row['title'],
               int(row['year']),
               float(row['imdb_rating']),
               genres,
               actors,
               row['director']
            )

    @staticmethod
    def _create_full_movie(tx, title, year, rating, genres, actors, director):

        #Movie Node
        tx.run("""
           MERGE (m:Movie {title: $title})
           SET m.year = $year,
               m.rating = $rating
        """, title = title, year = year, rating = rating)
        

        #Genres
        for g in genres:
            tx.run("""
               MERGE (genre:Genre {name: $g})
               WITH genre
               MATCH (m:Movie {title: $title})
               MERGE (m)-[:HAS_GENRE]->(genre)
            """, g = g, title = title)

        #Actors
        for a in actors:
            tx.run("""
               MERGE (actor:Actor {name: $a})
               WITH actor
               MATCH (m:Movie {title: $title})
               MERGE (actor)-[:ActED_IN]->(m)
            """, a = a, title = title)

        #Director
        tx.run("""
           MERGE (d:Director {name: $director})
           WITH d
           MATCH (m:Movie {title: $title})
           MERGE (d)-[:DIRECTED]->(m)
        """, director = director, title = title)

# %%
app = MovieGraph(URI, USER, PASSWORD)

app.add_movies(final_data.head(4000)) 

app.close()

print("Graph created!")
# Out:
# ---------------------------------------------------------------------------
# GqlError                                  Traceback (most recent call last)
# GqlError: {gql_status: 22N31} {gql_status_description: error: data exception - invalid properties in merge pattern. 'MERGE' cannot be used with graph element property values that are null or NaN.} {message: 22N31: 'MERGE' cannot be used with graph element property values that are null or NaN.} {diagnostic_record: {'_classification': 'CLIENT_ERROR', 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}} {raw_classification: CLIENT_ERROR}
#
# The above exception was the direct cause of the following exception:
#
# ClientError                               Traceback (most recent call last)
# Cell In[49], line 3
#       1 app = MovieGraph(URI, USER, PASSWORD)
# ----> 3 app.add_movies(final_data.head(4000))
#       5 app.close()
#       7 print("Graph created!")
#
# Cell In[46], line 22, in MovieGraph.add_movies(self, df)
#      19 genres = row['genres'] if isinstance(row['genres'], list) else []
#      20 actors = row['actors'] if isinstance(row['actors'], list) else []
# ---> 22 session.execute_write(
#      23    self._create_full_movie,
#      24    row['title'],
#      25    int(row['year']),
#      26    float(row['imdb_rating']),
#      27    genres,
#      28    actors,
#      29    row['director']
#      30 )
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/neo4j/_sync/work/session.py:720, in Session.execute_write(self, transaction_function, *args, **kwargs)
#     667 @NonConcurrentMethodChecker._non_concurrent_method
#     668 def execute_write(
#     669     self,
#    (...)
#     674     **kwargs: _P.kwargs,
#     675 ) -> _R:
#     676     """
#     677     Execute a unit of work in a managed write transaction.
#     678
#    (...)
#     718     .. versionadded:: 5.0
#     719     """  # noqa: E501 example code isn't too long
# --> 720     return self._run_transaction(
#     721         WRITE_ACCESS,
#     722         TelemetryAPI.TX_FUNC,
#     723         transaction_function,
#     724         args,
#     725         kwargs,
#     726     )
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/neo4j/_sync/work/session.py:543, in Session._run_transaction(self, access_mode, api, transaction_function, args, kwargs)
#     541 tx = self._transaction
#     542 try:
# --> 543     result = transaction_function(tx, *args, **kwargs)
#     544 except asyncio.CancelledError:
#     545     # if cancellation callback has not been called yet:
#     546     if self._transaction is not None:
#
# Cell In[46], line 62, in MovieGraph._create_full_movie(tx, title, year, rating, genres, actors, director)
#      54     tx.run("""
#      55        MERGE (actor:Actor {name: $a})
#      56        WITH actor
#      57        MATCH (m:Movie {title: $title})
#      58        MERGE (actor)-[:ActED_IN]->(m)
#      59     """, a = a, title = title)
#      61 #Director
# ---> 62 tx.run("""
#      63    MERGE (d:Director {name: $director})
#      64    WITH d
#      65    MATCH (m:Movie {title: $title})
#      66    MERGE (d)-[:DIRECTED]->(m)
#      67 """, director = director, title = title)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/neo4j/_sync/work/transaction.py:201, in TransactionBase.run(self, query, parameters, **kwparameters)
#     198 self._results.append(result)
#     200 parameters = dict(parameters or {}, **kwparameters)
# --> 201 result._tx_ready_run(query, parameters)
#     203 return result
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/neo4j/_sync/work/result.py:178, in Result._tx_ready_run(self, query, parameters)
#     174 def _tx_ready_run(self, query, parameters):
#     175     # BEGIN+RUN does not carry any extra on the RUN message.
#     176     # BEGIN {extra}
#     177     # RUN "query" {parameters} {extra}
# --> 178     self._run(query, parameters, None, None, None, None, None, None)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/neo4j/_sync/work/result.py:237, in Result._run(self, query, parameters, db, imp_user, access_mode, bookmarks, notifications_min_severity, notifications_disabled_classifications)
#     235 self._pull()
#     236 self._connection.send_all()
# --> 237 self._attach()
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/neo4j/_sync/work/result.py:439, in Result._attach(self)
#     437 if self._exhausted is False:
#     438     while self._attached is False:
# --> 439         self._connection.fetch_message()
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/neo4j/_sync/io/_common.py:193, in ConnectionErrorHandler.__getattr__.<locals>.outer.<locals>.inner(*args, **kwargs)
#     191 def inner(*args, **kwargs):
#     192     try:
# --> 193         func(*args, **kwargs)
#     194     except (Neo4jError, ServiceUnavailable, SessionExpired) as exc:
#     195         assert not inspect.iscoroutinefunction(self.__on_error)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/neo4j/_sync/io/_bolt.py:867, in Bolt.fetch_message(self)
#     863 # Receive exactly one message
#     864 tag, fields = self.inbox.pop(
#     865     hydration_hooks=self.responses[0].hydration_hooks
#     866 )
# --> 867 res = self._process_message(tag, fields)
#     868 self.idle_since = monotonic()
#     869 return res
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/neo4j/_sync/io/_bolt6.py:548, in Bolt6x0._process_message(self, tag, fields)
#     546 self._enrich_error_diagnostic_record(summary_metadata)
#     547 try:
# --> 548     response.on_failure(summary_metadata or {})
#     549 except (ServiceUnavailable, DatabaseUnavailable):
#     550     if self.pool:
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/neo4j/_sync/io/_common.py:263, in Response.on_failure(self, metadata)
#     261 handler = self.handlers.get("on_summary")
#     262 Util.callback(handler)
# --> 263 raise self._hydrate_error(metadata)
#
# ClientError: {neo4j_code: Neo.ClientError.Statement.SemanticError} {message: Cannot merge the following node because of null property value for 'name': (:Director {name: null})} {gql_status: 22G03} {gql_status_description: error: data exception - invalid value type}
